# %%
import json
import numpy as np

with open("outputs_final_2.0/vocab.json", "r") as f:
    w2i = json.load(f)

# %%
W1 = np.load("outputs_final_2.0/CBOW_d100_w4_W1.npy")

# %%
word = "institute"

if word in w2i:
    vec = W1[w2i[word]]
    print(word + " - " + ", ".join(f"{v:.4f}" for v in vec))
else:
    print("Word not found")
# Out:
# institute - 0.1654, -1.6780, 0.3164, 0.6464, 0.0633, 0.0234, -0.9181, 0.9871, -0.0176, 0.3884, -0.5009, -1.0401, 0.0049, 1.1755, 0.3024, -0.2104, 0.5304, -0.2199, -0.0735, 0.2860, -0.1448, -0.3455, -0.5396, -0.4272, -0.5280, -0.2302, 0.2103, -0.2784, -1.2368, -0.4450, -0.3950, 1.2037, 0.9113, 1.2517, 0.3175, 1.1505, -0.3612, -0.5662, 0.8861, 0.2779, 0.1039, 0.1647, -0.6993, 0.4813, 0.4105, 1.8198, -1.3282, 0.2843, 0.4232, 1.0064, -0.0886, 0.6076, -0.3050, 0.0200, 0.7271, -0.5899, -0.1317, 1.0034, -0.8636, -1.1819, 0.0814, -0.3376, -0.3198, -0.3751, -1.2078, -0.3413, -0.1995, 0.0097, -0.5584, -1.2967, 0.3395, -0.1460, -0.5159, 0.1428, 0.2007, -0.2573, 0.7801, -0.6689, 0.1541, 0.6162, 0.9977, 0.5295, -0.1322, 0.3960, 0.3366, -0.0098, -0.2220, 0.5881, -0.1486, -0.1061, 0.0780, 0.1183, 0.6440, 0.0032, -0.8043, 0.3223, -1.0617, 0.5806, -0.1788, -0.3875
